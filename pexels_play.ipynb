# %%
import requests
from call_retrievers import get_pexels_images

# %%
headers = {
    'Authorization': 't0NmJLY2HIIgOP5I2tzWwCyt1rYyif5Vke7VYNEZqoV7aPCVecbbK8tW'
}
response = requests.get('https://api.pexels.com/v1/search?query=nature', headers=headers)

# %%
response.json()['photos']
# Out:
# [{'id': 2325447,
#   'width': 5184,
#   'height': 3456,
#   'url': 'https://www.pexels.com/photo/hot-air-balloon-2325447/',
#   'photographer': 'Francesco Ungaro',
#   'photographer_url': 'https://www.pexels.com/@francesco-ungaro',
#   'photographer_id': 21273,
#   'avg_color': '#85928B',
#   'src': {'original': 'https://images.pexels.com/photos/2325447/pexels-photo-2325447.jpeg',
#    'large2x': 'https://images.pexels.com/photos/2325447/pexels-photo-2325447.jpeg?auto=compress&cs=tinysrgb&dpr=2&h=650&w=940',
#    'large': 'https://images.pexels.com/photos/2325447/pexels-photo-2325447.jpeg?auto=compress&cs=tinysrgb&h=650&w=940',
#    'medium': 'https://images.pexels.com/photos/2325447/pexels-photo-2325447.jpeg?auto=compress&cs=tinysrgb&h=350',
#    'small': 'https://images.pexels.com/photos/2325447/pexels-photo-2325447.jpeg?auto=compress&cs=tinysrgb&h=130',
# ...

# %%
get_pexels_images('nature')[0]
# Out:
# ['https://images.pexels.com/photos/2325447/pexels-photo-2325447.jpeg',
#  'https://images.pexels.com/photos/886521/pexels-photo-886521.jpeg',
#  'https://images.pexels.com/photos/1133957/pexels-photo-1133957.jpeg',
#  'https://images.pexels.com/photos/158063/bellingrath-gardens-alabama-landscape-scenic-158063.jpeg',
#  'https://images.pexels.com/photos/1386604/pexels-photo-1386604.jpeg',
#  'https://images.pexels.com/photos/459335/pexels-photo-459335.jpeg',
#  'https://images.pexels.com/photos/250591/pexels-photo-250591.jpeg',
#  'https://images.pexels.com/photos/906150/pexels-photo-906150.jpeg',
#  'https://images.pexels.com/photos/247599/pexels-photo-247599.jpeg',
#  'https://images.pexels.com/photos/1108572/pexels-photo-1108572.jpeg']

# %%
get_pexels_images(query='city',photographer='Francesco Ungaro')[0]
# Out:
# []
