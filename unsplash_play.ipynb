# %%
import requests
from call_retrievers import get_unsplash_images

# %%
key = 'qrb9ob5MxEzMXiA-C11TVOrYGiob2NwEzpHiAXGwmRU'

response = requests.get(f'https://api.unsplash.com/photos/?client_id={key}')
response.json()
# Out:
# [{'id': 'OgDjEjTqURQ',
#   'slug': 'a-small-black-and-white-bird-sitting-on-top-of-a-block-OgDjEjTqURQ',
#   'alternative_slugs': {'en': 'a-small-black-and-white-bird-sitting-on-top-of-a-block-OgDjEjTqURQ',
#    'es': 'un-pequeno-pajaro-blanco-y-negro-sentado-en-lo-alto-de-un-bloque-OgDjEjTqURQ',
#    'ja': 'ブロックの上に座っている小さな黒と白の鳥-OgDjEjTqURQ',
#    'fr': 'un-petit-oiseau-noir-et-blanc-assis-au-sommet-dun-pate-de-maisons-OgDjEjTqURQ',
#    'it': 'un-piccolo-uccello-in-bianco-e-nero-seduto-in-cima-a-un-blocco-OgDjEjTqURQ',
#    'ko': '블록-위에-앉아있는-작은-흑백-새-OgDjEjTqURQ',
#    'de': 'ein-kleiner-schwarz-weisser-vogel-der-auf-einem-block-sitzt-OgDjEjTqURQ',
#    'pt': 'um-pequeno-passaro-preto-e-branco-sentado-no-topo-de-um-bloco-OgDjEjTqURQ'},
#   'created_at': '2025-02-15T01:29:27Z',
#   'updated_at': '2025-02-17T17:07:54Z',
#   'promoted_at': None,
#   'width': 4000,
#   'height': 5000,
#   'color': '#d9d9d9',
#   'blur_hash': 'LKOgHD%M?vof_NM{M{Rjt6ofIUxu',
#   'description': None,
# ...

# %%
get_unsplash_images(photo_id='OgDjEjTqURQ')
# Out:
# (['https://images.unsplash.com/photo-1739582814657-10931286d7a5?ixid=M3w3MDU0Mzh8MHwxfGFsbHx8fHx8fHx8fDE3Mzk4MTMzOTh8&ixlib=rb-4.0.3'],
#  [{'id': 'OgDjEjTqURQ',
#    'slug': 'a-small-black-and-white-bird-sitting-on-top-of-a-block-OgDjEjTqURQ',
#    'alternative_slugs': {'en': 'a-small-black-and-white-bird-sitting-on-top-of-a-block-OgDjEjTqURQ',
#     'es': 'un-pequeno-pajaro-blanco-y-negro-sentado-en-lo-alto-de-un-bloque-OgDjEjTqURQ',
#     'ja': 'ブロックの上に座っている小さな黒と白の鳥-OgDjEjTqURQ',
#     'fr': 'un-petit-oiseau-noir-et-blanc-assis-au-sommet-dun-pate-de-maisons-OgDjEjTqURQ',
#     'it': 'un-piccolo-uccello-in-bianco-e-nero-seduto-in-cima-a-un-blocco-OgDjEjTqURQ',
#     'ko': '블록-위에-앉아있는-작은-흑백-새-OgDjEjTqURQ',
#     'de': 'ein-kleiner-schwarz-weisser-vogel-der-auf-einem-block-sitzt-OgDjEjTqURQ',
#     'pt': 'um-pequeno-passaro-preto-e-branco-sentado-no-topo-de-um-bloco-OgDjEjTqURQ'},
#    'created_at': '2025-02-15T01:29:27Z',
#    'updated_at': '2025-02-17T17:07:54Z',
# ...
